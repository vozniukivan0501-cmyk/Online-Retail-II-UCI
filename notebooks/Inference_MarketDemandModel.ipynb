# %%
import pandas as pd

import config
from config import start_date, tick_size
import data_loader
from TimeEmulator import TimeEmulator
from config import tick_size
from data_loader import PROCESSED_DATA_DIR, IPC_PATH
from features import MarketDemandModel_data_transformation

# %%
df = pd.read_parquet(PROCESSED_DATA_DIR / 'online_retail.parquet')

# %%
MD_Emulate = TimeEmulator(
    start_date = config.start_date,
    df = df
)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 MD_Emulate = TimeEmulator(
#       2     start_date = config.start_date,
#       3     df = df
#       4 )
#
# File ~\Documents\ML\Online Retail II UCI\src\TimeEmulator.py:24, in TimeEmulator.__init__(self, start_date, df)
#      20     self.current_datetime = pd.to_datetime(start_date)
#      22 self.history = []
# ---> 24 self.demand_predictor = MarketDemandModel(
#      25     MODELS_DIR / 'MarketDemandModel.joblib',
#      26     CONFIG_FILES_DIR / 'MarketDemandModelEncoder.joblib',
#      27     history_df = df[df['InvoiceDate'] < self.current_datetime]
#      28 )
#      30 self.current_tick_data = df[df['InvoiceDate'] == self.current_datetime]
#
# File ~\Documents\ML\Online Retail II UCI\src\ModelClasses.py:13, in __init__(self, model_path, enc_path, history_df)
# ...

# %%
prediction = MD_Emulate.emulate_time_change(n_ticks = 7, tick_size = config.tick_size)
# Out:
# Current date:2011-09-06 00:00:00
# Current date:2011-09-07 00:00:00
# Current date:2011-09-08 00:00:00
# Current date:2011-09-09 00:00:00
# Current date:2011-09-10 00:00:00
# Current date:2011-09-11 00:00:00
# Current date:2011-09-12 00:00:00

# %%
prediction.to_parquet(IPC_PATH / 'MD_prediction_buffer.parquet')
